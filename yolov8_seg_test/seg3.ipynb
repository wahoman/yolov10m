# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("wahoman-fmp8j").project("ex-czzwv")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.31, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to ex-1 in yolov8:: 100%|██████████| 156/156 [00:00<00:00, 3908.32it/s]

# %%
from ultralytics import YOLO

model = YOLO('yolov8m-seg.pt')  # load a pretrained YOLOv8n detection model

# %%
model.train(data='C:/Users/SSTLabs/Desktop/yolov8_3/ex-1/data.yaml', epochs=1, patience=30, batch=8)
# Out:
# Ultralytics YOLOv8.2.31  Python-3.11.8 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %%
rf = Roboflow(api_key="")
project = rf.workspace("wahoman-fmp8j").project("x-ray-pypdj")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.31, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to x-ray-2 in yolov8:: 100%|██████████| 492/492 [00:00<00:00, 3776.59it/s]

# %%
model.train(data='C:/Users/SSTLabs/Desktop/yolov8_3/x-ray-2/data.yaml', epochs=1, patience=30, batch=8)
# Out:
# Ultralytics YOLOv8.2.31  Python-3.11.8 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("wahoman-fmp8j").project("a-qtevi")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.31, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to a-1 in yolov8:: 100%|██████████| 176/176 [00:00<00:00, 3833.90it/s]

# %%
model.train(data='C:/Users/SSTLabs/Desktop/yolov8_3/a-1/data.yaml', epochs=1, patience=30, batch=8)
# Out:
# Ultralytics YOLOv8.2.31  Python-3.11.8 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("wahoman-fmp8j").project("ex-czzwv")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.31, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to ex-2 in yolov8:: 100%|██████████| 160/160 [00:00<00:00, 4193.52it/s]

# %%
model.train(data='C:/Users/SSTLabs/Desktop/yolov8_3/ex-2/data.yaml', epochs=1, patience=30, batch=8)
